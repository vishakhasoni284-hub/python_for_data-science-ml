# %%
import numpy as np

# %%
#numpy is an open source library that is used for handling scientific calculations
#we had list but we needed array so we used numpy that hadles array
#why we needed numpy ? through the difr
#list is hetrogenous and numpy is homogenous
#list takes more memory as compared to numpy
#list takes more execution time as compared to numpy

# %%
#pip install numpy ---> for vs code
#!pip install numpy ---> jupiter nootbook
#uv is just like pip but it is much faster than pip
#uv add -r requirments.txt ---> for uv in vs code
#( in requiremnets.txt file we can install all librarries )

# %%
a=[1,45,78,90]
type(a)

# %%
b=np.array(a)
b

# %%
type(b)

# %%
#user defined array

# %%
a=[]
size=int(input("Enter size : "))
for i in range(size):
  val=int(input("Enter items : "))
  a.append(val)
b=np.array(a)
b

# %%
a=[[1,2,3],[4,5,6],[7,8,9]]
b=np.array(a)
b

# %%
#b.shape==Total row and columns
#b.size==total elemets
print("Total rows and columns: ",b.shape)
print("Total elemenst : ",b.size)

# %%
#how to check dimanesions of an array
a=np.array([[1,2,3],[4,5,6]])
a.ndim

# %%
a=np.array([[[1,2,3],[4,5,6]]])
a.ndim

# %%
#images work on pixcels from 0 to 255 and pixcels work on matrix and we do operasstions on matrix and if we normalise the pixels that is sacle down.
#Deep learning work on artificial neurons and in that we define weight randomely and that weight is rondomly created by the help of numpy
#data sets ---> dumpy entry ---> with the help of--> random module--and it will be attached by pandas

# %%
#if ssomething shows black its pixel is 0 and if it shows white its pixels is 255 and if we normalise the pixels that is sacle down it reduces to 0 to 1
#0===black
#1==white

# %%
#pre defined functions in numpy
#1.zeors()---->it will create an array in which all the values will be zero either 1-d or multidimensions
#if we wnat to make boundaries black or want to add black shadows in that case we can use built in matrix called zeros of numpy

# %%
a=np.zeros(3)
a

# %%
b=np.zeros((3,4))
b

# %%
#for white shadows we will use ones()---> all valuies will be one

# %%
a=np.ones(4)
a

# %%
a=np.ones((4,5))
a
'''def ones(shape, dtype=None, order='C'):
    # shape must be a tuple (or something convertible to tuple)
    return _multiarray_umath.ones(shape, dtype, order)
    But if you write:

np.ones(4,5)
Python interprets this as:
shape = 4
dtype = 5
So it becomes two arguments, which is wrong ❌ because np.ones() only expects one required argument.
Why shape must be a tuple?
Because shapes can have:
Shape Example	Meaning
(5,)	1D array of length 5
(4,5)	2D array
(2,3,4)	3D array
One argument → can represent all shapes.
'''

# %%
a.shape

# %%
a.size

# %%
a = np.eye(3,4)   ### rows != columns ---> Asymmetric Matrix
a
'''np.eye() is defined as:
def eye(N, M=None, k=0, dtype=float, order='C'):
Here:
N = number of rows
M = number of columns (optional)
So you naturally pass two numbers, not one tuple:
np.eye(3,4)   # works ✅'''

# %%
# (4). diag() ---> It will create an array in which we can set our custom values at
# digonal position .

# %%
a = np.diag([1,34,67,90])
a

# %%
# (5). Random Module --->
# (a). Randint() ---> It will create an array randomly in a given range .
# syntax : np.random.randint(min_range, max_range, total_numbers)

# %%
a=np.random.randint(1,10,3)
a

# %%
# !mv /content/.ipynb /content/python_for_data-science-ml/
