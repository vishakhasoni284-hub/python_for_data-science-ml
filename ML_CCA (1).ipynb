# %%
#cca --> complete case analysis
#df ---> missing data ---> fiter missing data --->
#new_df=filtered_columns_in_which_we_have_moissing_data

#new_df---> missing data drop

#architecture ----> histogram--->
#past columns in whhich we have missing data
##past columns in whhich we have no missing data
#updated columns in which we have no missing data

#if past data archi overlaps to new data architecture--->
#it means we can drop missing data
#if past data architecture does not overlap to new data archit--->
#it means we can not drop missing data , we will fill missing data

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("/content/dsjob - dsjob.csv")

# %%
df.head()
# Out:
#    enrollee_id      city  city_development_index  gender  \
# 0        32403   city_41                   0.827    Male
# 1         9858  city_103                   0.920  Female
# 2        31806   city_21                   0.624    Male
# 3        27385   city_13                   0.827    Male
# 4        27724  city_103                   0.920    Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience    Full time course        Graduate
# 1  Has relevent experience       no_enrollment        Graduate
# 2   No relevent experience       no_enrollment     High School
# 3  Has relevent experience       no_enrollment         Masters
# 4  Has relevent experience       no_enrollment        Graduate
#
#   major_discipline experience company_size company_type last_new_job  \
# 0             STEM          9          <10          NaN            1
# 1             STEM          5          NaN      Pvt Ltd            1
# ...

# %%
df.isnull().sum()
# Out:
# enrollee_id                 0
# city                        0
# city_development_index      0
# gender                    508
# relevent_experience         0
# enrolled_university        31
# education_level            52
# major_discipline          312
# experience                  5
# company_size              622
# company_type              634
# last_new_job               40
# training_hours              0
# dtype: int64

# %%
cols=[var for var in df.columns if df[var].isnull().mean()<0.05 and df[var].isnull().mean()>0]
cols
# Out:
# ['enrolled_university', 'education_level', 'experience', 'last_new_job']

# %%
df[cols].sample(5)
# Out:
#      enrolled_university education_level experience last_new_job
# 1281       no_enrollment     High School          5            4
# 752        no_enrollment        Graduate        >20            4
# 43         no_enrollment        Graduate        >20            2
# 2041       no_enrollment        Graduate          6            2
# 1171       no_enrollment         Masters          7            1

# %%
df['experience'].value_counts()
# Out:
# experience
# >20    383
# 5      163
# 3      154
# 4      145
# 6      130
# 2      128
# 7      116
# 9      113
# 10      96
# 11      86
# 8       82
# <1      74
# 16      68
# 15      59
# 1       56
# 14      55
# 13      54
# 12      52
# 17      36
# 19      29
# 18      26
# 20      19
# Name: count, dtype: int64

# %%
len(df[cols].dropna())/len(df)
# Out:
# 0.9478628464067638

# %%
new_df=df[cols].dropna()
df.shape,new_df.shape
# Out:
# ((2129, 13), (2018, 4))

# %%
import matplotlib.pyplot as plt

# %%
fig=plt.figure()
ax=fig.add_subplot(111)

#original data
df['experience'].hist(bins=50,ax=ax,density=True,color='red')

#data after cca , the argument alpha makes the coolor transparent, so
#so we can see the overlay of tyhe 2 distribution
new_df['experience'].hist(bins=50,ax=ax,color='green',density=True,alpha=0.8)
# Out:
# <Axes: >

# %%
df=pd.read_csv("/content/covid_toy - covid_toy.csv")

# %%
cols=[var for var in df.columns if df[var].isnull().mean()<0.5 and df[var].isnull().mean()>0]
cols
# Out:
# ['fever']

# %%
df[cols].sample(5)
# Out:
#     fever
# 18   98.0
# 92  102.0
# 8   100.0
# 31  103.0
# 28  104.0

# %%
len(df[cols].dropna())/len(df)
# Out:
# 0.9

# %%
new_df=df[cols].dropna()
df.shape,new_df.shape
# Out:
# ((100, 6), (90, 1))

# %%
fig=plt.figure()
ax=fig.add_subplot(111)

#original data
df['fever'].hist(bins=50,ax=ax,density=True,color='red')

#data after cca , the argument alpha makes the coolor transparent, so
#so we can see the overlay of tyhe 2 distribution
new_df['fever'].hist(bins=50,ax=ax,color='green',density=True,alpha=0.8)
# Out:
# <Axes: >
